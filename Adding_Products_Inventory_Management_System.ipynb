# %%
fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'1001': {'expiry': '2-8-2021',
#   'manufacture': '5-5-2021',
#   'name': 'Choco Cake',
#   'price': 100,
#   'quantity': 34},
#  '1002': {'expiry': '2-9-2021',
#   'manufacture': '15-3-2021',
#   'name': 'Milk Cake',
#   'price': 800,
#   'quantity': 100},
#  '1003': {'expiry': '4-11-2021',
#   'manufacture': '23-2-2021',
#   'name': 'Drink',
#   'price': 85,
#   'quantity': 100},
#  '1004': {'expiry': '13-8-2021',
#   'manufacture': '25-5-2021',
#   'name': 'Candy',
#   'price': 5,
#   'quantity': 1000},
#  '1005': {'expiry': '10-11-2021',
#   'manufacture': 'N/A',
#   'name': 'Pen',
#   'price': 20,
#   'quantity': 100},
#  '1006': {'expiry': '22-8-2021',
#   'manufacture': 'N/A',
#   'name': 'Phone',
#   'price': 50000,
#   'quantity': 10},
#  '1007': {'expiry': '27-10-2021',
#   'manufacture': 'N/A',
#   'name': 'Mic',
#   'price': 1500,
#   'quantity': 0},
#  '1008': {'expiry': '2-11-2021',
#   'manufacture': '12-3-2021',
#   'name': 'Case',
#   'price': 599,
# ...

# %%
product_id = str(input("Enter Product Id: "))
name = str(input("Enter name of product: "))
price = int(input("Enter price of product: "))
quantity = int(input("Enter quantity of product: "))
manufacture = input("Enter the manufacture date of product: ")
expiry = input("Enter the expiry date of product: ")


record[product_id] = {'name': name, 'price': price, 'quantity': quantity, 'manufacture': manufacture, 'expiry':expiry}

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id: 2030
# Enter name of product: Godrej Haircolor
# Enter price of product: 20
# Enter quantity of product: 30
# Enter the manufacture date of product: 17-8-2021
# Enter the expiry date of product: 12-12-2021
